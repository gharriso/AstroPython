# %%
import sympy
from sympy import init_printing
init_printing()
from sympy import init_session
init_session()

from sympy import *
x, y, z, t = symbols('x y z t')
k, m, n = symbols('k m n', integer=True)
f, g, h = symbols('f g h', cls=Function)
init_printing() # doctest: +SKIP
Integral(sqrt(1/x),x)
# Out:
# IPython console for SymPy 1.13.2 (Python 3.12.2-64-bit) (ground types: python)
#
# These commands were executed:
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.13.2/
# ⌠
# ⎮     ___
# ⎮    ╱ 1
# ⎮   ╱  ─  dx
# ⎮ ╲╱   x
# ⌡

# %%
from sympy import *
x, y, z = symbols('x y z')
str(Integral(sqrt(1/x), x))
print(Integral(sqrt(1/x), x))

pprint(Integral(sqrt(1/x), x), use_unicode=False)
# Out:
# Integral(sqrt(1/x), x)
#   /
#  |
#  |     ___
#  |    / 1
#  |   /  -  dx
#  | \/   x
#  |
# /

# %%
print(latex(Integral(sqrt(1/x), x)))
# Out:
# \int \sqrt{\frac{1}{x}}\, dx

# %%
from sympy.printing.mathml import print_mathml
print_mathml(Integral(sqrt(1/x), x))
# Out:
# <apply>
# 	<int/>
# 	<bvar>
# 		<ci>x</ci>
# 	</bvar>
# 	<apply>
# 		<root/>
# 		<apply>
# 			<power/>
# 			<ci>x</ci>
# 			<cn>-1</cn>
# 		</apply>
# 	</apply>
# </apply>

# %%
simplify(sin(x)**2 + cos(x)**2)
simplify((x**3 + x**2 - x - 1)/(x**2 + 2*x + 1))
simplify(gamma(x)/gamma(x - 2))
# Out:
# (x - 2)⋅(x - 1)

# %%
from sympy import *
x, y, z = symbols('x y z')
init_printing(use_unicode=True)
functionX=3*x**2 + 1
functionX
#plot the sympy function
from sympy.plotting import plot
plot(functionX, (x, -10, 10), title='Plot of 3*x**2 + 1', xlabel='x', ylabel='f(x)', show=True)
