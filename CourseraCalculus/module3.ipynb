# %% [markdown]
# # Limits
#
# What does the function _want_ to do as it approaches some point which is possibly not defined for the function
#
# *Good example is functions that need to avoid divide by zero*
#
# This is determined by taking the x as close to the required value from either size without actually hitting that value
#
# ![image.png](attachment:image.png)

# %%
import sympy

# define sympy expression for sin(x)/x 
x= sympy.symbols('x')
expr = sympy.sin(x) / x
# Find the limit for x=0
limit_at_zero = sympy.limit(expr, x, 0)
# Print the limit
print(f"The limit of sin(x)/x as x approaches 0 is: {limit_at_zero}")
# plot the expression
sympy.plot(expr, (x, -10, 10), title='Plot of sin(x)/x', xlabel='x', ylabel='sin(x)/x', show=True)
# Out:
# The limit of sin(x)/x as x approaches 0 is: 1

# %% [markdown]
# ## There can only be one limit
# ![image.png](attachment:image.png)
# There is no official limit for this function, though sympy does try....

# %%
x= sympy.symbols('x')
expr = sympy.sin(sympy.pi/x )   
# Find the limit for x=0
limit_at_zero = sympy.limit(expr, x, 0)
#plot the function
print(f"The limit of sin(pi/x) as x approaches 0 is: {limit_at_zero}")
sympy.plot(expr, (x, -10, 10), title='Plot of sin(pi/x)', xlabel='x', ylabel='sin(pi/x)', show=True)
# Out:
# The limit of sin(pi/x) as x approaches 0 is: AccumBounds(-1, 1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sympy
x=sympy.symbols('x')
expr = 1/x**2
print("The limit of 1/x^2 as x approaches 0 is: ",sympy.limit(expr, x, 0))
# Find the limit when x is infinite
print("The limit of 1/x^2 as x approaches infinity is: ", sympy.limit(expr, x, sympy.oo))
# plot the expression
sympy.plot(expr, (x, -2, 2), title='Plot of 1/x^2', xlabel='x', ylabel='1/x^2', ylim=(0, 1000), show=True)
# Out:
# The limit of 1/x^2 as x approaches 0 is:  oo
# The limit of 1/x^2 as x approaches infinity is:  0

# %% [markdown]
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Here's how to use sympy to calculate the derivative using the limit definition

# %%
from sympy import * 
x,h= symbols('x h')
f=4*x**3 + 2*x**2 + 4
diffQuotient = (f.subs(x,x+h)-f.subs(x,x))/h
display(diffQuotient)
print(diffQuotient)
display(diffQuotient.simplify())
df=limit(diffQuotient,h,0)
display(df)
plot(f)
plot(df)
# Out:
# (-4*x**3 - 2*x**2 + 4*(h + x)**3 + 2*(h + x)**2)/h
# (-4*x**3 - 2*x**2 + 4*(h + x)**3 + 2*(h + x)**2)/h
# 4*h**2 + 12*h*x + 2*h + 12*x**2 + 4*x
# 12*x**2 + 4*x

# %%
Derivative(f,x).doit()
diff(f,x)
# Out:
# 12*x**2 + 4*x

# %% [markdown]
# ## Second derivative

# %%
diff(f,x,2).simplify()
# Out:
# 24*x + 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import symbols, exp
x= symbols('x')
q=(x+1)/(exp(1)**x)
df= q.diff(x)
slope=df.subs(x,1) 
print(f"The slope of the function (x+1)/(e^x) at x=1 is: {slope}")
yValue=q.subs(x,1).simplify()
tangentLine= slope * (x - 1) + yValue
print(f"The equation of the tangent line at x=1 is: {tangentLine.simplify()}")
# Out:
# The slope of the function (x+1)/(e^x) at x=1 is: -exp(-1)
# The equation of the tangent line at x=1 is: (3 - x)*exp(-1)
