# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import * 
x=symbols('x')
y=x**4
display(y.diff(x).simplify())
firstDiff=4*x**3
display(firstDiff)
# Out:
# 4*x**3
# 4*x**3

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
