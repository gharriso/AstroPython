# %% [markdown]
# # 12 · Python Quick Reference (Calculus + Units)Copy‑ready snippets for the exact operations used in this workbook set. Keep a cell like this open while you work the exam‑style puzzles.

# %% [markdown]
# ## Symbols & basics (SymPy)```pythonimport sympy as spx, t = sp.symbols('x t', real=True)f = (2*x**3)/(x+3)**4sp.diff(f, x)                  # derivative df/dxsp.integrate(sp.sin(x), x)     # indefinite integralsp.integrate(sp.sin(x), (x,0,sp.pi))  # definite integral```

# %% [markdown]
# ## Units (Astropy)```pythonfrom astropy import units as u, constants as const(5*u.kpc).to(u.m)L = (4*sp.pi * (10*u.Mpc)**2 * (2e-14*u.W/u.m**2)).to(u.W)```

# %% [markdown]
# ## Numeric integration & gradients (NumPy)```pythonimport numpy as npx = np.linspace(0, 10, 1001)y = 3*x**2area = np.trapz(y, x)          # ∫ y dxslope = np.gradient(y, x)      # dy/dx```

# %% [markdown]
# ## ODEs```pythont, k, y0 = sp.symbols('t k y0')y = y0*sp.exp(k*t)             # solution of ẏ = k yt_double = sp.log(2)/k```
