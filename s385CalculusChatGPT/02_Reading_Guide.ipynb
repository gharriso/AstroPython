# %% [markdown]
# # 02 · Reading Guide — Python-first calculus for S385This pack teaches the exact calculus you need for the S385 exam, using Python so you do not have to perform manual rules.## What you actually use- Symbolic differentiation and integration of polynomials, exponentials, and trigonometric functions.- Numerical integration for cosmology distances and ages.- Simple ODEs of the form $\dot M = f M$ (exponential growth/decay).- Special relativity kinematics: simultaneity, apparent speeds (algebraic relations).- Cosmology scalings: $\rho_m(z) = \rho_{m,0}(1+z)^3$, $T(z)=T_0(1+z)$, $n_\gamma\propto T^3$.- Lensing mass from Einstein angle and angular-diameter distances.- Distance modulus and apparent superluminal motion from proper motion.## Python stack- SymPy: `symbols`, `diff`, `integrate`, `series`, `lambdify`.- NumPy: arrays and `trapz` for numeric integrals.- Matplotlib: simple single-plot visuals.- Astropy: `units` and `constants` for physically consistent numbers.## Notation- Derivatives: $f'(x)$ and $\frac{df}{dx}$; time derivatives $\dot x$ and $\ddot x$.- Integrals: $\int f(x)\,dx$ and $\int_a^b f(x)\,dx$; Python mirrors these with `integrate`.## How the notebooks are structuredEach topic follows: **Definition → Applications → Key formulas → Worked Python examples → Exercises → Solutions**.## Quick map- 00, 01: Basics of differentiation and integration.- 03: Differentiation in Astrophysics.- 04: Integration and Areas.- 05: Numerical Integration in Cosmology.- 06: ODEs for Exponential Growth/Decay.- 07: Relativity — Lorentz & Simultaneity.- 08: Cosmology Scalings & Densities.- 09: Lensing Distances & Mass.- 10: Distance Modulus & Jets.- 11: Gradients & Multiple Integrals.- 12: Python Quick Reference.
